# %%
# !pip install wget

# %%
import numpy as np
import pandas as pd
import cv2
import os

# %%
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-01-cam0-d.zip -O data/images/fall-01-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-02-cam0-d.zip -O data/images/fall-02-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-03-cam0-d.zip -O data/images/fall-03-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-04-cam0-d.zip -O data/images/fall-04-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-05-cam0-d.zip -O data/images/fall-05-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-06-cam0-d.zip -O data/images/fall-06-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-07-cam0-d.zip -O data/images/fall-07-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-08-cam0-d.zip -O data/images/fall-08-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-09-cam0-d.zip -O data/images/fall-09-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-10-cam0-d.zip -O data/images/fall-10-cam0.zip

# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-11-cam0-d.zip -O data/images/fall-11-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-12-cam0-d.zip -O data/images/fall-12-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-13-cam0-d.zip -O data/images/fall-13-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-14-cam0-d.zip -O data/images/fall-14-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-15-cam0-d.zip -O data/images/fall-15-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-16-cam0-d.zip -O data/images/fall-16-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-17-cam0-d.zip -O data/images/fall-17-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-18-cam0-d.zip -O data/images/fall-18-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-19-cam0-d.zip -O data/images/fall-19-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-20-cam0-d.zip -O data/images/fall-20-cam0.zip

# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-21-cam0-d.zip -O data/images/fall-21-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-22-cam0-d.zip -O data/images/fall-22-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-23-cam0-d.zip -O data/images/fall-23-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-24-cam0-d.zip -O data/images/fall-24-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-25-cam0-d.zip -O data/images/fall-25-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-26-cam0-d.zip -O data/images/fall-26-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-27-cam0-d.zip -O data/images/fall-27-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-28-cam0-d.zip -O data/images/fall-28-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-29-cam0-d.zip -O data/images/fall-29-cam0.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-30-cam0-d.zip -O data/images/fall-30-cam0.zip

# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-01-cam1-d.zip -O data/images/fall-01-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-02-cam1-d.zip -O data/images/fall-02-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-03-cam1-d.zip -O data/images/fall-03-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-04-cam1-d.zip -O data/images/fall-04-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-05-cam1-d.zip -O data/images/fall-05-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-06-cam1-d.zip -O data/images/fall-06-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-07-cam1-d.zip -O data/images/fall-07-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-08-cam1-d.zip -O data/images/fall-08-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-09-cam1-d.zip -O data/images/fall-09-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-10-cam1-d.zip -O data/images/fall-10-cam1.zip

# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-11-cam1-d.zip -O data/images/fall-11-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-12-cam1-d.zip -O data/images/fall-12-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-13-cam1-d.zip -O data/images/fall-13-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-14-cam1-d.zip -O data/images/fall-14-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-15-cam1-d.zip -O data/images/fall-15-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-16-cam1-d.zip -O data/images/fall-16-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-17-cam1-d.zip -O data/images/fall-17-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-18-cam1-d.zip -O data/images/fall-18-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-19-cam1-d.zip -O data/images/fall-19-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-20-cam1-d.zip -O data/images/fall-20-cam1.zip

# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-21-cam1-d.zip -O data/images/fall-21-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-22-cam1-d.zip -O data/images/fall-22-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-23-cam1-d.zip -O data/images/fall-23-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-24-cam1-d.zip -O data/images/fall-24-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-25-cam1-d.zip -O data/images/fall-25-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-26-cam1-d.zip -O data/images/fall-26-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-27-cam1-d.zip -O data/images/fall-27-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-28-cam1-d.zip -O data/images/fall-28-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-29-cam1-d.zip -O data/images/fall-29-cam1.zip
# !wget http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-30-cam1-d.zip -O data/images/fall-30-cam1.zip
# Out:
# --2020-11-14 14:31:37--  http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-01-cam0-d.zip
# Resolving fenix.univ.rzeszow.pl (fenix.univ.rzeszow.pl)... 62.93.43.105
# Connecting to fenix.univ.rzeszow.pl (fenix.univ.rzeszow.pl)|62.93.43.105|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45129329 (43M) [application/zip]
# Saving to: ‘data/images/fall-01-cam0.zip’
#
# data/images/fall-01 100%[===================>]  43.04M   592KB/s    in 75s
#
# 2020-11-14 14:32:53 (588 KB/s) - ‘data/images/fall-01-cam0.zip’ saved [45129329/45129329]
#
# --2020-11-14 14:32:53--  http://fenix.univ.rzeszow.pl/~mkepski/ds/data/fall-02-cam0-d.zip
# Resolving fenix.univ.rzeszow.pl (fenix.univ.rzeszow.pl)... 62.93.43.105
# Connecting to fenix.univ.rzeszow.pl (fenix.univ.rzeszow.pl)|62.93.43.105|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29775081 (28M) [application/zip]
# Saving to: ‘data/images/fall-02-cam0.zip’
#
# ...

# %%
from zipfile import ZipFile 

# specifying the zip file name 
for cam in range(0, 2):
  for i in range(1, 31):
    num = str(i)
    if i < 10:
      num = "0" + num
    file_name = "data/images/fall-" + num + "-cam" + str(cam) + ".zip"
    with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
      zip.printdir() 
      print('Extracting all the files now...') 
      zip.extractall('data/images/') 
      print('Done!')
# Out:
# File Name                                             Modified             Size
# fall-01-cam0-d/                                2013-12-11 15:53:44            0
# fall-01-cam0-d/fall-01-cam0-d-001.png          2013-12-11 13:55:14       285940
# fall-01-cam0-d/fall-01-cam0-d-002.png          2013-12-11 13:55:14       294423
# fall-01-cam0-d/fall-01-cam0-d-003.png          2013-12-11 13:55:14       289099
# fall-01-cam0-d/fall-01-cam0-d-004.png          2013-12-11 13:55:14       295710
# fall-01-cam0-d/fall-01-cam0-d-005.png          2013-12-11 13:55:14       295431
# fall-01-cam0-d/fall-01-cam0-d-006.png          2013-12-11 13:55:14       296197
# fall-01-cam0-d/fall-01-cam0-d-007.png          2013-12-11 13:55:14       295381
# fall-01-cam0-d/fall-01-cam0-d-008.png          2013-12-11 13:55:14       269552
# fall-01-cam0-d/fall-01-cam0-d-009.png          2013-12-11 13:55:14       285047
# fall-01-cam0-d/fall-01-cam0-d-010.png          2013-12-11 13:55:14       286726
# ...
